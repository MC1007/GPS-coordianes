# %%
import pandas as pd
from geopy.exc import GeocoderTimedOut
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\bhava\Downloads\importers_.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Reg_no                           Company  \
# 0           0  2.022033e+10                      RAKESH VOHRA
# 1           2  2.022040e+10       TCP Homes and Decor Pvt Ltd
# 2           5  2.022040e+11  UMEEKA PACKAGING PRIVATE LIMITED
# 3           8  2.022040e+11    ESKAY NONWOVEN PRIVATE LIMITED
# 4          10  2.022040e+11       KIASK IMPEX PRIVATE LIMITED
#
#                                              Address        Mobile  \
# 0                           B-122 TAGORE GARDEN EXTN  9.810540e+09
# 1  Lower Ground floor, Neo Vikram CHS, New Link R...  9.820126e+09
# 2     C 308 BHAVESHWAR PLAZA LBS ROAD GHATKOPAR WEST  9.821117e+09
# 3  E- 42 D-I , II, INDUSTRIAL AREA KHUSHKHERA, BH...  9.311717e+09
# 4  3rd Floor, Plot NO 154, Sandesh Vihar, Near Ko...  9.311881e+09
#
#                            Email  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0  veetechinternational@yahoo.in         NaN         NaN         NaN
# 1     abhijeet@thecouchpotato.in         NaN         NaN         NaN
# 2        MEHTA.DARSHAN@GMAIL.COM         NaN         NaN         NaN
# 3      eskaynonwoven14@gmail.com         NaN         NaN         NaN
# 4   k2mimpexoverseas17@gmail.com         NaN         NaN         NaN
#
#    Unnamed: 9
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df= df.drop('Unnamed: 0',axis=1)

# %%
df = df.drop(['Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9'],axis=1)

# %%
df.head()
# Out:
#          Reg_no                           Company  \
# 0  2.022033e+10                      RAKESH VOHRA
# 1  2.022040e+10       TCP Homes and Decor Pvt Ltd
# 2  2.022040e+11  UMEEKA PACKAGING PRIVATE LIMITED
# 3  2.022040e+11    ESKAY NONWOVEN PRIVATE LIMITED
# 4  2.022040e+11       KIASK IMPEX PRIVATE LIMITED
#
#                                              Address        Mobile  \
# 0                           B-122 TAGORE GARDEN EXTN  9.810540e+09
# 1  Lower Ground floor, Neo Vikram CHS, New Link R...  9.820126e+09
# 2     C 308 BHAVESHWAR PLAZA LBS ROAD GHATKOPAR WEST  9.821117e+09
# 3  E- 42 D-I , II, INDUSTRIAL AREA KHUSHKHERA, BH...  9.311717e+09
# 4  3rd Floor, Plot NO 154, Sandesh Vihar, Near Ko...  9.311881e+09
#
#                            Email
# 0  veetechinternational@yahoo.in
# 1     abhijeet@thecouchpotato.in
# 2        MEHTA.DARSHAN@GMAIL.COM
# 3      eskaynonwoven14@gmail.com
# 4   k2mimpexoverseas17@gmail.com

# %%
from geopy.geocoders import ArcGIS

# %%
import requests

# %%
from geopy.geocoders import Here

# %%
key = 'Jv66CQhDjmGnEMNeJkNqeTQDmzqHzfSR'
url = 'https://www.mapquestapi.com/geocoding/v1/address?key='
loc = 'Z square mall,kanpur'
main_url = url + key + '&location = ' + loc
print(main_url)
# Out:
# https://www.mapquestapi.com/geocoding/v1/address?key=Jv66CQhDjmGnEMNeJkNqeTQDmzqHzfSR&location = Z square mall,kanpur

# %%
r = requests.get(main_url)
data = r.json()
location = data['locations'][0]
print(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 3>()
#       1 r = requests.get(main_url)
#       2 data = r.json()
# ----> 3 location = data['locations'][0]
#       4 print(data)
#
# KeyError: 'locations'

# %%
'''latitude_list= []
longitude_list =[]
from geopy.geocoders import ArcGIS

# Create an instance of the geocoder
geolocator = ArcGIS()

# Define the address that you want to convert to coordinates
#address = "MAYURESH COSMOS,401 SECTOR 11,CBD BELAPUR,NEAR SHREE KRISHNA UDUPI HOTEL,400614"

for address in df.Address:
    # Use the geocoder to get the coordinates of the address
    location = geolocator.geocode(address)
    if location is not None:
            latitude_list.append(location.latitude)
            longitude_list.append(location.longitude)
            print(location.latitude, location.longitude)
    else:
        print("Could not find coordinates for ")'''
# Out:
# 28.65178000000003 77.11616000000004
# 19.135867907238953 72.83542052808141
# 19.092670000000055 72.91208000000006
# 28.20480730307671 76.87015144795147
# 28.685796344619106 77.13789032382738
# 28.629650000000026 77.22479000000004
# 13.638835285557116 79.48860635360722
# 28.440159991588516 77.01328000846007
# 28.659232568650477 77.12386565068209
# 18.43569836000902 73.97999815919002
# 19.178980000000024 72.84352000000007
# 17.448602864197955 78.5059082040155
# 28.564872489274297 77.21928111403139
# 18.94986270525363 72.82718551037289
# 19.15620000062333 72.84858003857013
# 12.96027999043477 80.24626002658448
# 20.927530000000047 79.00379000000004
# 19.28959610003543 73.02578781214713
# 28.714570000000037 77.16251000000005
# 28.86689000000007 77.13490000000007
# 13.05592999470231 80.25422995921889
# 19.296400000000062 72.85228000000006
# 28.93789144021379 77.52763947397592
# 28.456371249656904 77.09715821169998
# 13.04701001525251 80.24065999325393
# 22.479240006059058 88.31279996238311
# 28.62642066176608 77.21496078820503
# 12.93529999113423 77.62171003856776
# 13.047349985245319 80.22293000492402
# 18.998180000000048 72.82813000000004
# 19.235040000000026 72.84159000000005
# 19.074399363821332 73.1282570881489
# 28.47166999637693 77.50618997845157
# 19.00756133561834 72.81863666432825
# 28.56874513500003 77.28381500000006
# 11.78848000000005 77.86893000000003
# 28.535394848234787 77.28520965826812
# 28.648195419982784 77.210996426047
# 22.55614330810547 88.40756769130162
# 19.011282566990953 72.82382807573421
# 19.121544748771083 72.91011333827876
# 21.234270000000038 72.87590000000006
# -8.55860999999993 125.57361000000003
# 19.161290817861133 72.85443845851866
# 28.65172000000007 77.23114000000004
# 19.164762449637756 72.93783496494096
# 21.17323459724759 79.15348862944221
# 28.550580000000025 77.12276000000008
# 28.627865209150052 77.22818581296424
# 28.705940000000055 77.18455000000006
# 22.576904397000078 88.34797500000008
# 28.496966139513425 77.15106442005361
# 13.008800468721807 80.23021991525879
# 18.536350000000027 73.87598000000008
# 23.097530000000063 72.66806000000008
# 12.650244014990804 80.14815910865973
# 28.539390000000026 77.27240000000006
# 19.38777745850888 72.88045472052316
# 28.664907573370897 77.1489619857622
# 28.800471787951306 77.1421918807303
# 12.937190000000044 77.61068000000006
# 28.669320000000027 77.09171000000003
# 19.00744834318655 72.83627896150276
# 24.85605000000004 88.02723000000003
# 22.55858791404704 88.42007338315383
# 19.422610000000077 72.87000000000006
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:179, in HTTPConnection._new_conn(self)
#     178 except SocketTimeout:
# --> 179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#     185 except SocketError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x000001A9DC9C4CA0>, 'Connection to geocode.arcgis.com timed out. (connect timeout=1)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810     log.warning(
#     811         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     812     )
# --> 813     return self.urlopen(
#     814         method,
#     815         url,
#     816         body,
#     817         headers,
#     818         retries,
#     819         redirect,
#     820         assert_same_host,
#     821         timeout=timeout,
#     822         pool_timeout=pool_timeout,
#     823         release_conn=release_conn,
#     824         chunked=chunked,
#     825         body_pos=body_pos,
#     826         **response_kw
#     827     )
#     829 # Handle redirect?
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:813, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     810     log.warning(
#     811         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     812     )
# --> 813     return self.urlopen(
#     814         method,
#     815         url,
#     816         body,
#     817         headers,
#     818         retries,
#     819         redirect,
#     820         assert_same_host,
#     821         timeout=timeout,
#     822         pool_timeout=pool_timeout,
#     823         release_conn=release_conn,
#     824         chunked=chunked,
#     825         body_pos=body_pos,
#     826         **response_kw
#     827     )
#     829 # Handle redirect?
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~\anaconda3\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='geocode.arcgis.com', port=443): Max retries exceeded with url: /arcgis/rest/services/World/GeocodeServer/findAddressCandidates?singleLine=328%2F15%2C+Jarod+-+Rasulabad+road%2C+Near+Referral+Hospital%2C+Jarod%2C+Vadodara+-+391510&f=json&maxLocations=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001A9DC9C4CA0>, 'Connection to geocode.arcgis.com timed out. (connect timeout=1)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\geopy\adapters.py:457, in RequestsAdapter._request(self, url, timeout, headers)
#     456 try:
# --> 457     resp = self.session.get(url, timeout=timeout, headers=headers)
#     458 except Exception as error:
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:542, in Session.get(self, url, **kwargs)
#     541 kwargs.setdefault('allow_redirects', True)
# --> 542 return self.request('GET', url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:507, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     506     if not isinstance(e.reason, NewConnectionError):
# --> 507         raise ConnectTimeout(e, request=request)
#     509 if isinstance(e.reason, ResponseError):
#
# ConnectTimeout: HTTPSConnectionPool(host='geocode.arcgis.com', port=443): Max retries exceeded with url: /arcgis/rest/services/World/GeocodeServer/findAddressCandidates?singleLine=328%2F15%2C+Jarod+-+Rasulabad+road%2C+Near+Referral+Hospital%2C+Jarod%2C+Vadodara+-+391510&f=json&maxLocations=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001A9DC9C4CA0>, 'Connection to geocode.arcgis.com timed out. (connect timeout=1)'))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# Input In [11], in <cell line: 11>()
#       8 # Define the address that you want to convert to coordinates
#       9 #address = "MAYURESH COSMOS,401 SECTOR 11,CBD BELAPUR,NEAR SHREE KRISHNA UDUPI HOTEL,400614"
#      11 for address in df.Address:
#      12     # Use the geocoder to get the coordinates of the address
# ---> 13     location = geolocator.geocode(address)
#      14     if location is not None:
#      15             latitude_list.append(location.latitude)
#
# File ~\anaconda3\lib\site-packages\geopy\geocoders\arcgis.py:173, in ArcGIS.geocode(self, query, exactly_one, timeout, out_fields)
#     171 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     172 callback = partial(self._parse_geocode, exactly_one=exactly_one)
# --> 173 return self._authenticated_call_geocoder(url, callback, timeout=timeout)
#
# File ~\anaconda3\lib\site-packages\geopy\geocoders\arcgis.py:265, in ArcGIS._authenticated_call_geocoder(self, url, parse_callback, timeout)
#     261 def _authenticated_call_geocoder(
#     262     self, url, parse_callback, *, timeout=DEFAULT_SENTINEL
#     263 ):
#     264     if not self.username:
# --> 265         return self._call_geocoder(url, parse_callback, timeout=timeout)
#     267     def query_callback():
#     268         call_url = "&".join((url, urlencode({"token": self.token})))
#
# File ~\anaconda3\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File ~\anaconda3\lib\site-packages\geopy\adapters.py:447, in RequestsAdapter.get_json(self, url, timeout, headers)
#     446 def get_json(self, url, *, timeout, headers):
# --> 447     resp = self._request(url, timeout=timeout, headers=headers)
#     448     try:
#     449         return resp.json()
#
# File ~\anaconda3\lib\site-packages\geopy\adapters.py:469, in RequestsAdapter._request(self, url, timeout, headers)
#     467         raise GeocoderServiceError(message)
#     468     else:
# --> 469         raise GeocoderUnavailable(message)
#     470 elif isinstance(error, requests.Timeout):
#     471     raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='geocode.arcgis.com', port=443): Max retries exceeded with url: /arcgis/rest/services/World/GeocodeServer/findAddressCandidates?singleLine=328%2F15%2C+Jarod+-+Rasulabad+road%2C+Near+Referral+Hospital%2C+Jarod%2C+Vadodara+-+391510&f=json&maxLocations=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001A9DC9C4CA0>, 'Connection to geocode.arcgis.com timed out. (connect timeout=1)'))

# %%
'''import pandas as pd
import requests

key = 'Jv66CQhDjmGnEMNeJkNqeTQDmzqHzfSR'
url = 'https://www.mapquestapi.com/geocoding/v1/address?key='
loc = 'E- 42 D-I , II, INDUSTRIAL AREA KHUSHKHERA, BHIWADI, Alwar, Rajasthan, 301019'
main_url = url + key + '&location=' + loc

# Send the geocoding request and parse the response
response = requests.get(main_url)
if response.status_code == 200:
    data = response.json()
    if 'results' in data and len(data['results']) > 0:
        result = data['results'][0]
        if 'locations' in result and len(result['locations']) > 0:
            location = result['locations'][0]
            latitude = location['latLng']['lat']
            longitude = location['latLng']['lng']
            print("Latitude:", latitude)
            print("Longitude:", longitude)
        else:
            print("No location found in API response.")
    else:
        print("No results found in API response.")
else:
    print("Geocoding request failed.")'''
# Out:
# 'import pandas as pd\nimport requests\n\nkey = \'Jv66CQhDjmGnEMNeJkNqeTQDmzqHzfSR\'\nurl = \'https://www.mapquestapi.com/geocoding/v1/address?key=\'\nloc = \'E- 42 D-I , II, INDUSTRIAL AREA KHUSHKHERA, BHIWADI, Alwar, Rajasthan, 301019\'\nmain_url = url + key + \'&location=\' + loc\n\n# Send the geocoding request and parse the response\nresponse = requests.get(main_url)\nif response.status_code == 200:\n    data = response.json()\n    if \'results\' in data and len(data[\'results\']) > 0:\n        result = data[\'results\'][0]\n        if \'locations\' in result and len(result[\'locations\']) > 0:\n            location = result[\'locations\'][0]\n            latitude = location[\'latLng\'][\'lat\']\n            longitude = location[\'latLng\'][\'lng\']\n            print("Latitude:", latitude)\n            print("Longitude:", longitude)\n        else:\n            print("No location found in API response.")\n    else:\n        print("No results found in API response.")\nelse:\n    print("Geocoding request failed.")'

# %%
key = 'Jv66CQhDjmGnEMNeJkNqeTQDmzqHzfSR'
url = 'https://www.mapquestapi.com/geocoding/v1/address?key='

# Define the list of addresses that you want to convert to coordinates
#addresses = ['Z square mall,kanpur','The Oberoi Udaivilas, Udaipur','Taj Mahal, Agra']

# Create empty lists to store the latitude and longitude coordinates
latitude_list = []
longitude_list = []

# Loop through each address and geocode it using MapQuest API
for address in df.Address:
    main_url = url + key + '&location=' + address
    response = requests.get(main_url)
    if response.status_code == 200:
        data = response.json()
        if 'results' in data and len(data['results']) > 0:
            result = data['results'][0]
            if 'locations' in result and len(result['locations']) > 0:
                location = result['locations'][0]
                latitude = location['latLng']['lat']
                longitude = location['latLng']['lng']
                latitude_list.append(latitude)
                longitude_list.append(longitude)
                #print("Address:", address)
                print("Latitude:", latitude)
                print("Longitude:", longitude)
                #print("--------------------------------------------------------")
            else:
                print("No location found in API response for address:", address)
        else:
            print("No results found in API response for address:", address)
    else:
        print("Geocoding request failed for address:", address)

# Create a pandas DataFrame to store the results
df = pd.DataFrame({'Address': addresses, 'Latitude': latitude_list, 'Longitude': longitude_list})

# Save the results to an Excel file
df.to_excel('location.xlsx', index=False)
# Out:
# Latitude: 28.65178
# Longitude: 77.11616
# Latitude: 19.14178
# Longitude: 72.83303
# Latitude: 19.09267
# Longitude: 72.91206
# Latitude: 28.20322
# Longitude: 76.8577
# Latitude: 28.69205
# Longitude: 77.14202
# Latitude: 28.58922
# Longitude: 77.30734
# Latitude: 13.72297
# Longitude: 79.48422
# Latitude: 28.41524
# Longitude: 76.99554
# Latitude: 28.70773
# Longitude: 77.10869
# Latitude: 18.43978
# Longitude: 73.97551
# Latitude: 19.17898
# Longitude: 72.84345
# Latitude: 38.89037
# Longitude: -77.03196
# Latitude: 28.56821
# Longitude: 77.22292
# Latitude: 18.94862
# Longitude: 72.82636
# Latitude: 19.15629
# Longitude: 72.84862
# Latitude: 12.9602
# Longitude: 80.24623
# Latitude: 21.1322
# Longitude: 79.00445
# Latitude: 38.89037
# Longitude: -77.03196
# Latitude: 38.89037
# Longitude: -77.03196
# Latitude: 28.82555
# Longitude: 77.10939
# Latitude: 13.05601
# Longitude: 80.25421
# Latitude: 19.29721
# Longitude: 72.85236
# Latitude: 28.93039
# Longitude: 77.52236
# Latitude: 54.58558
# Longitude: -5.97398
# Latitude: 13.14679
# Longitude: 80.23414
# Latitude: 56.04067
# Longitude: -3.41979
# Latitude: 28.62479
# Longitude: 77.21375
# Latitude: 12.93507
# Longitude: 77.62217
# Latitude: 13.04746
# Longitude: 80.22295
# Latitude: 18.99538
# Longitude: 72.82819
# Latitude: 19.23501
# Longitude: 72.84293
# Latitude: 38.89037
# Longitude: -77.03196
# Latitude: 28.51382
# Longitude: 77.51513
# Latitude: 19.01115
# Longitude: 72.82091
# Latitude: 28.53803
# Longitude: 77.28856
# Latitude: 20.92852
# Longitude: 77.75082
# Latitude: 28.5078
# Longitude: 77.29738
# Latitude: 38.89037
# Longitude: -77.03196
# Latitude: 22.51296
# Longitude: 88.40494
# Latitude: 19.01186
# Longitude: 72.82385
# Latitude: 19.11952
# Longitude: 72.90877
# Latitude: 38.89037
# Longitude: -77.03196
# Latitude: 28.55146
# Longitude: 77.12299
# Latitude: 19.16348
# Longitude: 72.85198
